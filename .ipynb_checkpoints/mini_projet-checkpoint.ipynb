# %%
import sys
import requests
from time import sleep
import numpy as np
import pandas as pd
from pandas.io.json import json_normalize
import json

# %%
# Variable initialisation
cpt=0
N_request = 10
category = ['tiny','small','medium','large']
listCourse = []

# %%
def request(category,cpt) :
	r = requests.get('http://tortues.ecoquery.os.univ-lyon1.fr:8080/'+str(category))
	r_json = r.json()
	recs = r_json['tortoises']
	df = pd.json_normalize(recs)
	df['iterration_update'] = cpt
	return df

# %%
while cpt < N_request :
	print('Requete '+str(cpt+1))
	res = request('tiny',cpt)
	listCourse.append(res)
	sleep(3)
	cpt += 1
	
df = pd.concat(listCourse)
df['vitesse'] = 0
# Out:
# Requete 1
# Requete 2
# Requete 3
# Requete 4
# Requete 5
# Requete 6
# Requete 7
# Requete 8
# Requete 9
# Requete 10

# %%
df.loc[df.iterration_update == 0,'vitesse'] = -1
df.head(20)
# Out:
#    id    top  position  iterration_update  vitesse
# 0   0  20084   3622254                  0       -1
# 1   1  20084   7340318                  0       -1
# 2   2  20084   4048788                  0       -1
# 3   3  20084   3881997                  0       -1
# 4   4  20084   3734933                  0       -1
# 5   5  20084   2690880                  0       -1
# 6   6  20084   6928980                  0       -1
# 7   7  20084   3902080                  0       -1
# 8   8  20084   2104800                  0       -1
# 9   9  20084   3598998                  0       -1
# 0   0  20085   3622471                  1        0
# 1   1  20085   7340685                  1        0
# 2   2  20085   4049110                  1        0
# 3   3  20085   3882392                  1        0
# 4   4  20085   3735117                  1        0
# 5   5  20085   2691072                  1        0
# 6   6  20085   6929325                  1        0
# 7   7  20085   3902241                  1        0
# 8   8  20085   2104959                  1        0
# 9   9  20085   3599218                  1        0

# %%
df = df.sort_values(by=['id','top'])

# %%
df ['ecart_position_avec_precedent'] = df.groupby('id')['position'].diff()

# %%
df
# Out:
#     id    top  position  iterration_update  vitesse  \
# 0    0  20084   3622254                  0       -1
# 0    0  20085   3622471                  1        0
# 0    0  20086   3622784                  2        0
# 0    0  20087   3622923                  3        0
# 0    0  20089   3623492                  4        0
# ..  ..    ...       ...                ...      ...
# 9    9  20090   3600133                  5        0
# 9    9  20091   3600344                  6        0
# 9    9  20092   3600550                  7        0
# 9    9  20093   3600828                  8        0
# 9    9  20094   3601070                  9        0
#
#     ecart_position_avec_precedent
# 0                             NaN
# 0                           217.0
# 0                           313.0
# 0                           139.0
# 0                           569.0
# ..                            ...
# 9                           194.0
# 9                           211.0
# 9                           206.0
# 9                           278.0
# 9                           242.0
#
# [100 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8,6))
ax.set_ylim([99999, 999999])
plt.ylim([df['position'].min(),df['position'].max()])
for i, g in df.groupby('id'):
    g.plot(x='iterration_update', y='position', ax=ax, label=str(i))

plt.show()
